# %%
import numpy as np 
import pandas as pd
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
educate=pd.read_csv('Placement_Data_Full_Class.csv')
educate
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
educate.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
educate.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
educate.columns=['SerialNo','Gender','SecEd','SecBoard','HigherSec',
                        'HigherSecBoard','HigherSecSpecialization',
                        'DegreePercentage','DegreeType','WorkExperience',
                        'EmployabilityTest','Specialization','MBAPercentage','Status','Salary']
educate
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 0           1      M  67.00   Others      91.00         Others
# 1           2      M  79.33  Central      78.33         Others
# 2           3      M  65.00  Central      68.00        Central
# 3           4      M  56.00  Central      52.00        Central
# 4           5      M  85.80  Central      73.60        Central
# ..        ...    ...    ...      ...        ...            ...
# 210       211      M  80.60   Others      82.00         Others
# 211       212      M  58.00   Others      60.00         Others
# 212       213      M  67.00   Others      67.00         Others
# 213       214      F  74.00   Others      66.00         Others
# 214       215      M  62.00  Central      58.00         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 0                  Commerce             58.00   Sci&Tech             No
# ...

# %%
educate.shape
# Out:
# (215, 15)

# %%
educate.size
# Out:
# 3225

# %%
plt.savefig('Data Sample')
educate.describe()
# Out:
#          SerialNo       SecEd   HigherSec  DegreePercentage  \
# count  215.000000  215.000000  215.000000        215.000000
# mean   108.000000   67.303395   66.333163         66.370186
# std     62.209324   10.827205   10.897509          7.358743
# min      1.000000   40.890000   37.000000         50.000000
# 25%     54.500000   60.600000   60.900000         61.000000
# 50%    108.000000   67.000000   65.000000         66.000000
# 75%    161.500000   75.700000   73.000000         72.000000
# max    215.000000   89.400000   97.700000         91.000000
#
#        EmployabilityTest  MBAPercentage         Salary
# count         215.000000     215.000000     148.000000
# mean           72.100558      62.278186  288655.405405
# std            13.275956       5.833385   93457.452420
# min            50.000000      51.210000  200000.000000
# 25%            60.000000      57.945000  240000.000000
# 50%            71.000000      62.000000  265000.000000
# ...

# %%
educate[(educate['Gender']=='F') & (educate['WorkExperience']=='Yes')]
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 15         16      F  65.00  Central      75.00        Central
# 23         24      F  77.40   Others      60.00         Others
# 25         26      F  52.58   Others      54.60        Central
# 33         34      F  87.00   Others      65.00         Others
# 41         42      F  74.00   Others      63.16         Others
# 44         45      F  77.00   Others      73.00         Others
# 80         81      F  69.00   Others      62.00         Others
# 85         86      F  83.84   Others      89.83         Others
# 89         90      F  84.00   Others      75.00         Others
# 96         97      F  76.00  Central      70.00        Central
# 100       101      F  45.00   Others      57.00         Others
# 102       103      F  77.00   Others      61.00         Others
# 121       122      F  64.00  Central      67.00         Others
# 122       123      F  66.50  Central      66.80        Central
# ...

# %%
educate.sort_values(['EmployabilityTest'], ascending=False).head(10)
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 152       153      F  75.40   Others       60.5        Central
# 24         25      M  76.50   Others       97.7         Others
# 206       207      M  41.00  Central       42.0        Central
# 118       119      M  76.00  Central       80.0        Central
# 4           5      M  85.80  Central       73.6        Central
# 138       139      F  82.00   Others       64.0         Others
# 116       117      M  68.20  Central       72.8        Central
# 189       190      F  54.00  Central       77.6         Others
# 72         73      M  84.86   Others       67.0         Others
# 95         96      M  73.00  Central       78.0         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 152                 Science             84.00   Sci&Tech             No
# 24                  Science             78.86   Sci&Tech             No
# ...

# %%
educate[(educate['DegreeType']=='Sci&Tech') & (educate['Status']=='Placed')]
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 0           1      M  67.00   Others      91.00         Others
# 1           2      M  79.33  Central      78.33         Others
# 7           8      M  82.00  Central      64.00        Central
# 22         23      F  69.80   Others      60.80         Others
# 23         24      F  77.40   Others      60.00         Others
# 24         25      M  76.50   Others      97.70         Others
# 37         38      F  79.00  Central      76.00        Central
# 39         40      M  81.00   Others      68.00         Others
# 53         54      M  80.00   Others      70.00         Others
# 59         60      M  52.60  Central      65.58         Others
# 62         63      F  86.50   Others      64.20         Others
# 69         70      M  73.00  Central      73.00        Central
# 70         71      M  82.00   Others      61.00         Others
# 77         78      M  64.00   Others      80.00         Others
# ...

# %%
educate[(educate['DegreeType']=='Comm&Mgmt') & (educate['Status']=='Placed')]
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 2           3      M  65.00  Central       68.0        Central
# 4           5      M  85.80  Central       73.6        Central
# 8           9      M  73.00  Central       79.0        Central
# 10         11      M  58.00  Central       61.0        Central
# 11         12      M  69.60  Central       68.4        Central
# ..        ...    ...    ...      ...        ...            ...
# 207       208      M  83.33  Central       78.0         Others
# 209       210      M  62.00  Central       72.0        Central
# 210       211      M  80.60   Others       82.0         Others
# 212       213      M  67.00   Others       67.0         Others
# 213       214      F  74.00   Others       66.0         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 2                      Arts              64.0  Comm&Mgmt             No
# ...

# %%
educate.sort_values(['MBAPercentage'], ascending=False).head(10)
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 19         20      M  60.00   Others      67.00         Others
# 128       129      M  80.40  Central      73.40        Central
# 85         86      F  83.84   Others      89.83         Others
# 167       168      M  67.90   Others      62.00         Others
# 165       166      F  63.30  Central      78.33         Others
# 210       211      M  80.60   Others      82.00         Others
# 24         25      M  76.50   Others      97.70         Others
# 107       108      M  82.00   Others      90.00         Others
# 125       126      F  84.00  Central      73.00        Central
# 33         34      F  87.00   Others      65.00         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 19                     Arts             70.00  Comm&Mgmt            Yes
# 128                 Science             77.72   Sci&Tech            Yes
# ...

# %%
top10=educate.sort_values(['Salary'], ascending=False).head(10)
top10
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 119       120      M  60.80  Central      68.40        Central
# 150       151      M  71.00  Central      58.66        Central
# 177       178      F  73.00  Central      97.00         Others
# 163       164      M  63.00   Others      67.00         Others
# 77         78      M  64.00   Others      80.00         Others
# 174       175      M  73.24   Others      50.83         Others
# 53         54      M  80.00   Others      70.00         Others
# 4           5      M  85.80  Central      73.60        Central
# 95         96      M  73.00  Central      78.00         Others
# 39         40      M  81.00   Others      68.00         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 119                Commerce             64.60  Comm&Mgmt            Yes
# 150                 Science             58.00   Sci&Tech            Yes
# ...

# %%
x=educate['EmployabilityTest']
x.plot(kind='box', figsize=(8, 6))

plt.title('Employability Test')
plt.ylabel('Percentage')

plt.savefig('Employability test.png')

plt.style.use('seaborn-dark-palette')
plt.show()

# %%
educate['EmployabilityTest'].mean()
# Out:
# 72.10055813953488

# %%
educate['Salary'].mean()
# Out:
# 288655.4054054054

# %%
educate[(educate['EmployabilityTest']>72) & (educate['Status']=='Placed')]
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 1           2      M  79.33  Central      78.33         Others
# 2           3      M  65.00  Central      68.00        Central
# 4           5      M  85.80  Central      73.60        Central
# 8           9      M  73.00  Central      79.00        Central
# 21         22      F  79.00   Others      76.00         Others
# ..        ...    ...    ...      ...        ...            ...
# 200       201      M  69.00   Others      60.00         Others
# 204       205      F  74.00   Others      73.00         Others
# 207       208      M  83.33  Central      78.00         Others
# 210       211      M  80.60   Others      82.00         Others
# 211       212      M  58.00   Others      60.00         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 1                   Science             77.48   Sci&Tech            Yes
# ...

# %%
educate[(educate['EmployabilityTest']<72) & (educate['Status']=='Placed')]
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 0           1      M  67.00   Others      91.00         Others
# 7           8      M  82.00  Central      64.00        Central
# 10         11      M  58.00  Central      61.00        Central
# 11         12      M  69.60  Central      68.40        Central
# 13         14      F  77.00  Central      87.00        Central
# ..        ...    ...    ...      ...        ...            ...
# 203       204      M  55.68   Others      61.33         Others
# 205       206      M  61.00   Others      62.00         Others
# 209       210      M  62.00  Central      72.00        Central
# 212       213      M  67.00   Others      67.00         Others
# 213       214      F  74.00   Others      66.00         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 0                  Commerce             58.00   Sci&Tech             No
# ...

# %%
educate[(educate['EmployabilityTest']>72) & (educate['Status']=='Not Placed')]
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 6           7      F  46.00   Others      49.20         Others
# 14         15      M  62.00  Central      47.00        Central
# 25         26      F  52.58   Others      54.60        Central
# 29         30      M  62.00  Central      67.00        Central
# 65         66      M  54.00   Others      47.00         Others
# 68         69      F  69.70  Central      47.00        Central
# 75         76      F  59.00  Central      62.00         Others
# 79         80      F  69.00  Central      62.00        Central
# 82         83      M  63.00  Central      67.00        Central
# 87         88      M  59.60  Central      51.00        Central
# 97         98      F  70.50  Central      62.50         Others
# 105       106      M  59.00  Central      64.00         Others
# 109       110      M  52.00  Central      63.00         Others
# 120       121      M  58.00   Others      40.00         Others
# ...

# %%
educate[(educate['EmployabilityTest']<72) & (educate['Status']=='Not Placed')]
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 3           4      M  56.00  Central      52.00        Central
# 5           6      M  55.00   Others      49.80         Others
# 9          10      M  58.00  Central      70.00        Central
# 12         13      F  47.00  Central      55.00         Others
# 17         18      F  55.00  Central      67.00        Central
# 18         19      F  63.00  Central      66.00        Central
# 31         32      F  67.00  Central      53.00        Central
# 34         35      M  62.00   Others      51.00         Others
# 36         37      M  51.00  Central      44.00        Central
# 41         42      F  74.00   Others      63.16         Others
# 42         43      M  49.00   Others      39.00        Central
# 45         46      F  76.00  Central      64.00        Central
# 46         47      F  70.89   Others      71.98         Others
# 49         50      F  50.00   Others      37.00         Others
# ...

# %%
educate.plot(kind='scatter', x='EmployabilityTest', y='MBAPercentage', figsize=(10, 6), color='darkblue')

plt.title('MBA Contribution to Employability test')
plt.xlabel('Employability Percentage')
plt.ylabel('MBA Percentage')
plt.savefig('MBA Contribution to Employability test')

plt.show()

# %%
educate.plot(kind='scatter', x='EmployabilityTest', y='DegreePercentage', figsize=(10, 6), color='purple')

plt.title('Undergraduate Degree Contribution to Employability test')
plt.xlabel('Employability Percentage')
plt.ylabel('Degree Percentage')
plt.savefig('Undergraduate Degree Contribution to Employability test')


plt.show()

# %%
b=educate['Salary']
b.plot(kind='box', figsize=(8, 6))

plt.title('Salary offered to Candidates')
plt.ylabel('Dollars')

plt.show()

# %%
n=top10['DegreeType']
m=top10['Salary']
plt.figure(figsize=(8,5),dpi=100)


plt.bar(n ,m , color='orange')

plt.xticks(n)

plt.title('Top salaries and degree undertaken')

plt.xlabel('Degree Type')

plt.ylabel('Salary')
plt.savefig('Top salaries and degree undertaken')

plt.show()

# %%
k=educate['Specialization']
z=educate['Salary']
plt.figure(figsize=(8,5),dpi=100)


plt.bar(k,z , color='red')

plt.xticks(k)

plt.title('Salary Awarded as per Specialization')

plt.xlabel('Specialization')

plt.ylabel('Salary')
plt.savefig('Salary Awarded as per Specialization')

plt.show()

# %%
educate[(educate['DegreeType']=='Comm&Mgmt') & (educate['Specialization']=='Mkt&Fin')]
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 2           3      M  65.00  Central       68.0        Central
# 4           5      M  85.80  Central       73.6        Central
# 6           7      F  46.00   Others       49.2         Others
# 8           9      M  73.00  Central       79.0        Central
# 9          10      M  58.00  Central       70.0        Central
# ..        ...    ...    ...      ...        ...            ...
# 206       207      M  41.00  Central       42.0        Central
# 207       208      M  83.33  Central       78.0         Others
# 209       210      M  62.00  Central       72.0        Central
# 210       211      M  80.60   Others       82.0         Others
# 212       213      M  67.00   Others       67.0         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 2                      Arts              64.0  Comm&Mgmt             No
# ...

# %%
french=educate[(educate['EmployabilityTest']>86.52) & (educate['Status']=='Placed')]
french
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 4           5      M  85.80  Central      73.60        Central
# 8           9      M  73.00  Central      79.00        Central
# 21         22      F  79.00   Others      76.00         Others
# 23         24      F  77.40   Others      60.00         Others
# 24         25      M  76.50   Others      97.70         Others
# 26         27      M  71.00   Others      79.00         Others
# 33         34      F  87.00   Others      65.00         Others
# 39         40      M  81.00   Others      68.00         Others
# 43         44      M  87.00   Others      87.00         Others
# 44         45      F  77.00   Others      73.00         Others
# 53         54      M  80.00   Others      70.00         Others
# 70         71      M  82.00   Others      61.00         Others
# 71         72      M  75.00   Others      70.29         Others
# 72         73      M  84.86   Others      67.00         Others
# ...

# %%
educate[(educate['EmployabilityTest']>86.52)].nunique()
# Out:
# SerialNo                   39
# Gender                      2
# SecEd                      33
# SecBoard                    2
# HigherSec                  33
# HigherSecBoard              2
# HigherSecSpecialization     2
# DegreePercentage           28
# DegreeType                  3
# WorkExperience              2
# EmployabilityTest          25
# Specialization              2
# MBAPercentage              38
# Status                      2
# Salary                     18
# dtype: int64

# %%
educate[(educate['EmployabilityTest']>86.52)].mean()
# Out:
# SerialNo                114.923077
# SecEd                    73.117949
# HigherSec                70.948205
# DegreePercentage         69.504359
# EmployabilityTest        92.456923
# MBAPercentage            65.004615
# Salary               313290.322581
# dtype: float64

# %%
french=educate[(educate['EmployabilityTest']>86.52)]
french
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 4           5      M  85.80  Central      73.60        Central
# 8           9      M  73.00  Central      79.00        Central
# 21         22      F  79.00   Others      76.00         Others
# 23         24      F  77.40   Others      60.00         Others
# 24         25      M  76.50   Others      97.70         Others
# 26         27      M  71.00   Others      79.00         Others
# 33         34      F  87.00   Others      65.00         Others
# 39         40      M  81.00   Others      68.00         Others
# 43         44      M  87.00   Others      87.00         Others
# 44         45      F  77.00   Others      73.00         Others
# 53         54      M  80.00   Others      70.00         Others
# 65         66      M  54.00   Others      47.00         Others
# 70         71      M  82.00   Others      61.00         Others
# 71         72      M  75.00   Others      70.29         Others
# ...

# %%
french1=french.dropna()

# %%
count, bin_edges = np.histogram(french1['Salary'],15)
french1['Salary'].plot(kind='hist', figsize=(8, 5),color='yellow')

plt.title('Histogram of salaries of candidates with above 86.52 Employability results') 
plt.ylabel('Number of Candidates') 
plt.xlabel('Salary in Dollars')
plt.xticks=bin_edges

plt.savefig('Histogram of salaries of candidates with above 86.52 Employability results.png')

plt.show()

# %%
french1
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 4           5      M  85.80  Central      73.60        Central
# 8           9      M  73.00  Central      79.00        Central
# 21         22      F  79.00   Others      76.00         Others
# 23         24      F  77.40   Others      60.00         Others
# 24         25      M  76.50   Others      97.70         Others
# 26         27      M  71.00   Others      79.00         Others
# 33         34      F  87.00   Others      65.00         Others
# 39         40      M  81.00   Others      68.00         Others
# 43         44      M  87.00   Others      87.00         Others
# 44         45      F  77.00   Others      73.00         Others
# 53         54      M  80.00   Others      70.00         Others
# 70         71      M  82.00   Others      61.00         Others
# 71         72      M  75.00   Others      70.29         Others
# 72         73      M  84.86   Others      67.00         Others
# ...

# %%
educate[(educate['EmployabilityTest']<=86.52) & (educate['Status']=='Placed')]
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 0           1      M  67.00   Others      91.00         Others
# 1           2      M  79.33  Central      78.33         Others
# 2           3      M  65.00  Central      68.00        Central
# 7           8      M  82.00  Central      64.00        Central
# 10         11      M  58.00  Central      61.00        Central
# ..        ...    ...    ...      ...        ...            ...
# 205       206      M  61.00   Others      62.00         Others
# 209       210      M  62.00  Central      72.00        Central
# 211       212      M  58.00   Others      60.00         Others
# 212       213      M  67.00   Others      67.00         Others
# 213       214      F  74.00   Others      66.00         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 0                  Commerce             58.00   Sci&Tech             No
# ...

# %%
educate[(educate['EmployabilityTest']<=86.52)].nunique()
# Out:
# SerialNo                   176
# Gender                       2
# SecEd                       85
# SecBoard                     2
# HigherSec                   83
# HigherSecBoard               2
# HigherSecSpecialization      3
# DegreePercentage            75
# DegreeType                   3
# WorkExperience               2
# EmployabilityTest           75
# Specialization               2
# MBAPercentage              168
# Status                       2
# Salary                      38
# dtype: int64

# %%
educate[(educate['EmployabilityTest']<=86.52)].mean()
# Out:
# SerialNo                106.465909
# SecEd                    66.014943
# HigherSec                65.310511
# DegreePercentage         65.675682
# EmployabilityTest        67.589773
# MBAPercentage            61.674034
# Salary               282128.205128
# dtype: float64

# %%
german=educate[(educate['EmployabilityTest']<=86.52)]
german
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 0           1      M  67.00   Others      91.00         Others
# 1           2      M  79.33  Central      78.33         Others
# 2           3      M  65.00  Central      68.00        Central
# 3           4      M  56.00  Central      52.00        Central
# 5           6      M  55.00   Others      49.80         Others
# ..        ...    ...    ...      ...        ...            ...
# 205       206      M  61.00   Others      62.00         Others
# 209       210      M  62.00  Central      72.00        Central
# 211       212      M  58.00   Others      60.00         Others
# 212       213      M  67.00   Others      67.00         Others
# 213       214      F  74.00   Others      66.00         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 0                  Commerce             58.00   Sci&Tech             No
# ...

# %%
nkk=german['Salary']
ekn=german['EmployabilityTest']
plt.bar(ekn,nkk)
plt.show()

# %%
german1=german.dropna()
german1
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 0           1      M  67.00   Others      91.00         Others
# 1           2      M  79.33  Central      78.33         Others
# 2           3      M  65.00  Central      68.00        Central
# 7           8      M  82.00  Central      64.00        Central
# 10         11      M  58.00  Central      61.00        Central
# ..        ...    ...    ...      ...        ...            ...
# 205       206      M  61.00   Others      62.00         Others
# 209       210      M  62.00  Central      72.00        Central
# 211       212      M  58.00   Others      60.00         Others
# 212       213      M  67.00   Others      67.00         Others
# 213       214      F  74.00   Others      66.00         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 0                  Commerce             58.00   Sci&Tech             No
# ...

# %%
count, bin_edges = np.histogram(german1['Salary'],15)
german1['Salary'].plot(kind='hist', figsize=(8, 5),color='indigo')

plt.title('Histogram of salaries of candidates with <= 86.52 Employability results') 
plt.ylabel('Number of Candidates') 
plt.xlabel('Salary in Dollars')
plt.xticks=bin_edges

plt.savefig('Histogram of salaries of candidates with less than or equal to 86.52 Employability results.png')

plt.show()

# %%
kamau=educate['Salary']
nyawi=educate['EmployabilityTest']


plt.bar(nyawi,kamau,color='green')
plt.title('Salary awarded as per the employability test',loc='center',pad= None)

plt.xlabel('Employability Test Percentage')
plt.ylabel('Salary in Dollars')
plt.savefig('Salary awarded as per the employability test')

plt.show()

# %%
peter=educate['DegreeType']
john=educate['EmployabilityTest']
plt.figure(figsize=(8,5),dpi=100)


plt.bar(peter,john , color='brown')


plt.title('Employability of candidates as per the degree type')

plt.xlabel('Degree Type')

plt.ylabel('Employability Percentage')
plt.savefig('Employability of candidates as per the degree type')

plt.show()

# %%
daniel=educate['Specialization']
david=educate['EmployabilityTest']
plt.figure(figsize=(8,5),dpi=100)


plt.bar(daniel,david , color='yellow')



plt.title('Employability of candidates as per the specialization')

plt.xlabel('Specialization')

plt.ylabel('Employability Percentage')

plt.savefig('Employability of candidates as per the specialization')

plt.show()

# %%
from scipy import stats

# %%
EmpTest = educate.groupby('EmployabilityTest')
EmpTest

# %%
educate1=educate.dropna()
educate1
# Out:
#      SerialNo Gender  SecEd SecBoard  HigherSec HigherSecBoard  \
# 0           1      M  67.00   Others      91.00         Others
# 1           2      M  79.33  Central      78.33         Others
# 2           3      M  65.00  Central      68.00        Central
# 4           5      M  85.80  Central      73.60        Central
# 7           8      M  82.00  Central      64.00        Central
# ..        ...    ...    ...      ...        ...            ...
# 209       210      M  62.00  Central      72.00        Central
# 210       211      M  80.60   Others      82.00         Others
# 211       212      M  58.00   Others      60.00         Others
# 212       213      M  67.00   Others      67.00         Others
# 213       214      F  74.00   Others      66.00         Others
#
#     HigherSecSpecialization  DegreePercentage DegreeType WorkExperience  \
# 0                  Commerce             58.00   Sci&Tech             No
# ...

# %%
Emp1 = educate[educate['EmployabilityTest'] >86.52]['MBAPercentage']
Emp2 = educate[educate['EmployabilityTest'] <= 86.52]['MBAPercentage']
stats.ttest_ind(Emp1,Emp2 )
# Out:
# Ttest_indResult(statistic=3.299723328302674, pvalue=0.001134416064103159)

# %%
Emp3 = educate1[educate1['EmployabilityTest'] >86.52]['Salary']
Emp4 = educate1[educate1['EmployabilityTest'] <= 86.52]['Salary']
stats.ttest_ind(Emp3,Emp4 )
# Out:
# Ttest_indResult(statistic=1.6604901835999577, pvalue=0.09896204457513294)
